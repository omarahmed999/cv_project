# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
import cv2
import os
import xml.etree.ElementTree as ET

# %%
import cv2
import os
import xml.etree.ElementTree as ET

# Set paths
images_path = 'images'
annotations_path = 'annotations'

# Pick a sample file
sample_file = 'maksssksksss0.png'
image_path = os.path.join(images_path, sample_file)
annotation_path = os.path.join(annotations_path, sample_file.replace('.png', '.xml'))

# Load image
image = cv2.imread(image_path)

# Parse XML
tree = ET.parse(annotation_path)
root = tree.getroot()

# Loop through all objects (faces)
for obj in root.findall('object'):
    label = obj.find('name').text
    bbox = obj.find('bndbox')
    x_min = int(bbox.find('xmin').text)
    y_min = int(bbox.find('ymin').text)
    x_max = int(bbox.find('xmax').text)
    y_max = int(bbox.find('ymax').text)
    
    # Draw bounding box and label
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
    cv2.putText(image, label, (x_min, y_min - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

# Display the image
cv2.imshow('Sample Image with Bounding Boxes', image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def preprocess_image(image, target_size=(224, 224)):
    """
    Resize and normalize the image.
    - image: Input image as a NumPy array (BGR)
    - target_size: Tuple (width, height)
    Returns: Preprocessed image (float32 normalized)
    """
    # Resize
    resized = cv2.resize(image, target_size)
    
    # Normalize to [0, 1]
    normalized = resized.astype(np.float32) / 255.0
    
    return normalized

# %%
import cv2
import numpy as np

def adjust_contrast(image, alpha=1.5, beta=0):
    """
    Adjust contrast and brightness of an image.
    alpha: Contrast control (1.0 means no change, higher means more contrast)
    beta: Brightness control (0 means no change)
    """
    return cv2.convertScaleAbs(image, alpha=alpha, beta=beta)

# Example usage
image = cv2.imread('images/maksssksksss1.png')
image_contrast = adjust_contrast(image)
cv2.imshow('Adjusted Contrast', image_contrast)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def threshold_image(image, thresh_value=127):
    """
    Apply binary thresholding to an image.
    The image is converted into a binary image where pixel values above
    the threshold are set to 255, and those below are set to 0.
    """
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)  # Convert to grayscale
    _, thresh_img = cv2.threshold(gray, thresh_value, 255, cv2.THRESH_BINARY)
    return thresh_img

# Example usage
image = cv2.imread('images/maksssksksss1.png')
thresh_img = threshold_image(image)
cv2.imshow('Thresholded Image', thresh_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def apply_blur(image, kernel_size=(5, 5)):
    """
    Apply Gaussian blur to an image.
    kernel_size: Size of the kernel (must be odd values like (3, 3), (5, 5))
    """
    return cv2.GaussianBlur(image, kernel_size, 0)

# Example usage
image = cv2.imread('images/maksssksksss1.png')
blurred_image = apply_blur(image)
cv2.imshow('Blurred Image', blurred_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
def apply_sharpening(image):
    """
    Apply sharpening filter to the image.
    Uses a kernel to highlight edges.
    """
    kernel = np.array([[0, -1, 0],
                       [-1, 5,-1],
                       [0, -1, 0]])  # Sharpening kernel
    return cv2.filter2D(image, -1, kernel)

# Example usage
image = cv2.imread('images/maksssksksss1.png')
sharpened_image = apply_sharpening(image)
cv2.imshow('Sharpened Image', sharpened_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

def preprocess_image(image):
    # Resize
    image = cv2.resize(image, (224, 224))
    
    # Contrast Adjustment
    image = adjust_contrast(image, alpha=1.5, beta=0)
    
    # Thresholding
    image = threshold_image(image, thresh_value=127)
    
    # Blurring
    image = apply_blur(image, kernel_size=(5, 5))
    
    # Sharpening
    image = apply_sharpening(image)
    
    # Normalize
    image = image.astype(np.float32) / 255.0
    
    return image

# Example usage
image = cv2.imread('images/maksssksksss2.png')
processed_image = preprocess_image(image)
cv2.imshow('Processed Image', processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Assume `image` is already loaded from before
preprocessed = preprocess_image(image)

# To display preprocessed image (scaled back to 0–255 for visualization)
cv2.imshow('Preprocessed Image', (preprocessed * 255).astype(np.uint8))
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import os
import cv2
import xml.etree.ElementTree as ET
import numpy as np

# Class names (map them to indices later)
CLASSES = ['with_mask', 'without_mask', 'mask_weared_incorrect']

def preprocess_image(image, target_size=(224, 224)):
    resized = cv2.resize(image, target_size)
    normalized = resized.astype(np.float32) / 255.0
    return normalized

def load_dataset(images_path='images', annotations_path='annotations', target_size=(224, 224)):
    X = []  # Preprocessed images
    y = []  # Corresponding bounding boxes and labels

    image_files = [f for f in os.listdir(images_path) if f.endswith('.png')]

    for img_file in image_files:
        xml_file = img_file.replace('.png', '.xml')
        xml_path = os.path.join(annotations_path, xml_file)

        if not os.path.exists(xml_path):
            continue  # Skip if annotation missing

        # Load and preprocess image
        image_path = os.path.join(images_path, img_file)
        image = cv2.imread(image_path)
        preprocessed = preprocess_image(image, target_size)
        X.append(preprocessed)

        # Parse XML annotation
        boxes = []
        tree = ET.parse(xml_path)
        root = tree.getroot()

        for obj in root.findall('object'):
            label = obj.find('name').text
            bbox = obj.find('bndbox')
            x_min = int(bbox.find('xmin').text)
            y_min = int(bbox.find('ymin').text)
            x_max = int(bbox.find('xmax').text)
            y_max = int(bbox.find('ymax').text)
            boxes.append([label, x_min, y_min, x_max, y_max])
        
        y.append(boxes)

    return X, y

# %%
X, y = load_dataset()

print(f"Loaded {len(X)} images.")
print("Sample image shape:", X[0].shape)
print("Sample annotation:", y[0])
# Out:
# Loaded 853 images.
# Sample image shape: (224, 224, 3)
# Sample annotation: [['without_mask', 79, 105, 109, 142], ['with_mask', 185, 100, 226, 144], ['without_mask', 325, 90, 360, 141]]

# %%
def load_dataset(images_path='images', annotations_path='annotations', target_size=(224, 224)):
    X = []
    y = []

    image_files = [f for f in os.listdir(images_path) if f.endswith('.png')]

    for img_file in image_files:
        xml_file = img_file.replace('.png', '.xml')
        xml_path = os.path.join(annotations_path, xml_file)

        if not os.path.exists(xml_path):
            continue

        # Load original image
        image_path = os.path.join(images_path, img_file)
        image = cv2.imread(image_path)
        orig_h, orig_w = image.shape[:2]

        # Resize and normalize
        preprocessed = preprocess_image(image, target_size)
        X.append(preprocessed)

        # Parse and normalize bounding boxes
        boxes = []
        tree = ET.parse(xml_path)
        root = tree.getroot()

        for obj in root.findall('object'):
            label = obj.find('name').text
            class_id = CLASSES.index(label)  # Convert label to integer

            bbox = obj.find('bndbox')
            x_min = int(bbox.find('xmin').text)
            y_min = int(bbox.find('ymin').text)
            x_max = int(bbox.find('xmax').text)
            y_max = int(bbox.find('ymax').text)

            # Normalize box to [0, 1] relative to original size
            x_min_norm = x_min / orig_w
            y_min_norm = y_min / orig_h
            x_max_norm = x_max / orig_w
            y_max_norm = y_max / orig_h

            boxes.append([class_id, x_min_norm, y_min_norm, x_max_norm, y_max_norm])

        y.append(boxes)

    return np.array(X), y

# %%
X, y = load_dataset()
print("Image shape:", X[0].shape)
print("Normalized boxes:", y[0])
# Out:
# Image shape: (224, 224, 3)
# Normalized boxes: [[1, 0.154296875, 0.28688524590163933, 0.212890625, 0.3879781420765027], [0, 0.361328125, 0.273224043715847, 0.44140625, 0.39344262295081966], [1, 0.634765625, 0.2459016393442623, 0.703125, 0.38524590163934425]]

# %%
def build_object_detection_model(input_shape=(224, 224, 3), num_classes=3):
    inputs = layers.Input(shape=input_shape)

    # Feature extractor
    x = layers.Conv2D(32, (3,3), activation='relu', padding='same')(inputs)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(64, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Conv2D(128, (3,3), activation='relu', padding='same')(x)
    x = layers.MaxPooling2D()(x)

    x = layers.Flatten()(x)
    x = layers.Dense(128, activation='relu')(x)

    # Output layer
    class_output = layers.Dense(num_classes, activation='softmax', name='class_output')(x)
    bbox_output = layers.Dense(4, activation='sigmoid', name='bbox_output')(x)  # [x_min, y_min, x_max, y_max]

    model = models.Model(inputs=inputs, outputs=[class_output, bbox_output])
    return model

# %%
model = build_object_detection_model()
model.compile(
    optimizer='adam',
    loss={
        'class_output': 'sparse_categorical_crossentropy',
        'bbox_output': 'mse'  # bounding box regression
    },
    metrics={
        'class_output': 'accuracy',
        'bbox_output': 'mse'
    }
)
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 224, 224, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d (Conv2D)               │ (None, 224, 224, 32)      │             896 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d (MaxPooling2D)  │ (None, 112, 112, 32)      │               0 │ conv2d[0][0]               │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_1 (Conv2D)             │ (None, 112, 112, 64)      │          18,496 │ max_pooling2d[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_1               │ (None, 56, 56, 64)        │               0 │ conv2d_1[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_2 (Conv2D)             │ (None, 56, 56, 128)       │          73,856 │ max_pooling2d_1[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ max_pooling2d_2               │ (None, 28, 28, 128)       │               0 │ conv2d_2[0][0]             │
# │ (MaxPooling2D)                │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ flatten (Flatten)             │ (None, 100352)            │               0 │ max_pooling2d_2[0][0]      │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │      12,845,184 │ flatten[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ class_output (Dense)          │ (None, 3)                 │             387 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bbox_output (Dense)           │ (None, 4)                 │             516 │ dense[0][0]                │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 12,939,335 (49.36 MB)
#  Trainable params: 12,939,335 (49.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
def prepare_labels(y):
    """
    Convert y from list of lists to:
    - class_labels: shape (num_samples,)
    - bbox_labels: shape (num_samples, 4)
    
    Only uses the first object per image.
    """
    class_labels = []
    bbox_labels = []

    for boxes in y:
        if len(boxes) == 0:
            continue  # Skip images with no objects
        
        first_obj = boxes[0]
        class_id, x_min, y_min, x_max, y_max = first_obj
        class_labels.append(class_id)
        bbox_labels.append([x_min, y_min, x_max, y_max])
    
    return np.array(class_labels), np.array(bbox_labels)

# %%
X, y = load_dataset()
class_labels, bbox_labels = prepare_labels(y)

print("Images:", X.shape)
print("Class labels:", class_labels.shape)
print("BBox labels:", bbox_labels.shape)
# Out:
# Images: (853, 224, 224, 3)
# Class labels: (853,)
# BBox labels: (853, 4)

# %%
model.fit(
    X,
    {
        'class_output': class_labels,
        'bbox_output': bbox_labels
    },
    epochs=20,
    batch_size=16,
    validation_split=0.2
)
# Out:
# Epoch 1/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 40s 830ms/step - bbox_output_loss: 0.0677 - bbox_output_mse: 0.0677 - class_output_accuracy: 0.8090 - class_output_loss: 0.8399 - loss: 0.9075 - val_bbox_output_loss: 0.0490 - val_bbox_output_mse: 0.0485 - val_class_output_accuracy: 0.8187 - val_class_output_loss: 0.6910 - val_loss: 0.7296
# Epoch 2/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 36s 837ms/step - bbox_output_loss: 0.0378 - bbox_output_mse: 0.0378 - class_output_accuracy: 0.8094 - class_output_loss: 0.6004 - loss: 0.6383 - val_bbox_output_loss: 0.0403 - val_bbox_output_mse: 0.0397 - val_class_output_accuracy: 0.8187 - val_class_output_loss: 0.6612 - val_loss: 0.6909
# Epoch 3/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 824ms/step - bbox_output_loss: 0.0334 - bbox_output_mse: 0.0334 - class_output_accuracy: 0.8433 - class_output_loss: 0.4505 - loss: 0.4838 - val_bbox_output_loss: 0.0436 - val_bbox_output_mse: 0.0431 - val_class_output_accuracy: 0.8129 - val_class_output_loss: 0.6686 - val_loss: 0.7065
# Epoch 4/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 40s
# Epoch 14/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 798ms/step - bbox_output_loss: 0.0056 - bbox_output_mse: 0.0056 - class_output_accuracy: 1.0000 - class_output_loss: 6.9448e-04 - loss: 0.0063 - val_bbox_output_loss: 0.0422 - val_bbox_output_mse: 0.0413 - val_class_output_accuracy: 0.7778 - val_class_output_loss: 2.3818 - val_loss: 2.3312
# Epoch 15/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 791ms/step - bbox_output_loss: 0.0040 - bbox_output_mse: 0.0040 - class_output_accuracy: 1.0000 - class_output_loss: 6.0695e-04 - loss: 0.0046 - val_bbox_output_loss: 0.0415 - val_bbox_output_mse: 0.0405 - val_class_output_accuracy: 0.7836 - val_class_output_loss: 2.3018 - val_loss: 2.2544
# Epoch 16/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 790ms/step - bbox_output_loss: 0.0027 - bbox_output_mse: 0.0027 - class_output_accuracy: 1.0000 - class_output_loss: 6.4392e-04 - loss: 0.0034 - val_bbox_output_loss: 0.0419 - val_bbox_output_mse: 0.0409 - val_class_output_accuracy: 0.7778 - val_class_output_loss: 2.3271 - val_loss: 2.2788
# Epoch 17/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - bbox_output_loss: 0.0029 - bbox_output_mse: 0.0029 - class_output_accuracy: 1.0000 - class_output_loss: 4.9649e-04 - loss: 0.0034 - val_bbox_output_loss: 0.0434 - val_bbox_output_mse: 0.0425 - val_class_output_accuracy: 0.7719 - val_class_output_loss: 2.3374 - val_loss: 2.2899
# Epoch 18/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 785ms/step - bbox_output_loss: 0.0030 - bbox_output_mse: 0.0030 - class_output_accuracy: 1.0000 - class_output_loss: 4.2620e-04 - loss: 0.0034 - val_bbox_output_loss: 0.0411 - val_bbox_output_mse: 0.0401 - val_class_output_accuracy: 0.7719 - val_class_output_loss: 2.2903 - val_loss: 2.2422
# Epoch 19/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 783ms/step - bbox_output_loss: 0.0026 - bbox_output_mse: 0.0026 - class_output_accuracy: 1.0000 - class_output_loss: 3.4344e-04 - loss: 0.0030 - val_bbox_output_loss: 0.0415 - val_bbox_output_mse: 0.0406 - val_class_output_accuracy: 0.7778 - val_class_output_loss: 2.3616 - val_loss: 2.3106
# Epoch 20/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 804ms/step - bbox_output_loss: 0.0031 - bbox_output_mse: 0.0031 - class_output_accuracy: 1.0000 - class_output_loss: 4.0776e-04 - loss: 0.0035 - val_bbox_output_loss: 0.0435 - val_bbox_output_mse: 0.0425 - val_class_output_accuracy: 0.7836 - val_class_output_loss: 2.2683 - val_loss: 2.2247

# %%
from sklearn.model_selection import train_test_split

X, y_raw = load_dataset()
cls, bbox = prepare_labels(y_raw)

X_train, X_test, cls_train, cls_test, bbox_train, bbox_test = train_test_split(
    X, cls, bbox, test_size=0.2, random_state=42, stratify=cls
)

# %%
history = model.fit(
    X_train,
    {'class_output': cls_train, 'bbox_output': bbox_train},
    epochs=20,
    batch_size=16,
    validation_data=(X_test, {'class_output': cls_test, 'bbox_output': bbox_test})
)
# Out:
# Epoch 1/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 41s 948ms/step - bbox_output_loss: 0.0169 - bbox_output_mse: 0.0170 - class_output_accuracy: 0.9431 - class_output_loss: 0.2934 - loss: 0.3105 - val_bbox_output_loss: 0.0213 - val_bbox_output_mse: 0.0215 - val_class_output_accuracy: 0.9298 - val_class_output_loss: 0.3369 - val_loss: 0.3596
# Epoch 2/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 36s 839ms/step - bbox_output_loss: 0.0146 - bbox_output_mse: 0.0146 - class_output_accuracy: 0.9643 - class_output_loss: 0.0955 - loss: 0.1101 - val_bbox_output_loss: 0.0150 - val_bbox_output_mse: 0.0152 - val_class_output_accuracy: 0.9240 - val_class_output_loss: 0.4345 - val_loss: 0.4586
# Epoch 3/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s
# Epoch 13/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 803ms/step - bbox_output_loss: 0.0018 - bbox_output_mse: 0.0018 - class_output_accuracy: 1.0000 - class_output_loss: 2.5973e-04 - loss: 0.0021 - val_bbox_output_loss: 0.0153 - val_bbox_output_mse: 0.0155 - val_class_output_accuracy: 0.9006 - val_class_output_loss: 0.6911 - val_loss: 0.7185
# Epoch 14/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 792ms/step - bbox_output_loss: 0.0018 - bbox_output_mse: 0.0018 - class_output_accuracy: 1.0000 - class_output_loss: 2.2301e-04 - loss: 0.0020 - val_bbox_output_loss: 0.0160 - val_bbox_output_mse: 0.0162 - val_class_output_accuracy: 0.9006 - val_class_output_loss: 0.6961 - val_loss: 0.7241
# Epoch 15/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 789ms/step - bbox_output_loss: 0.0018 - bbox_output_mse: 0.0018 - class_output_accuracy: 1.0000 - class_output_loss: 1.9011e-04 - loss: 0.0020 - val_bbox_output_loss: 0.0160 - val_bbox_output_mse: 0.0163 - val_class_output_accuracy: 0.9006 - val_class_output_loss: 0.6901 - val_loss: 0.7185
# Epoch 16/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 33s 772ms/step - bbox_output_loss: 0.0020 - bbox_output_mse: 0.0020 - class_output_accuracy: 1.0000 - class_output_loss: 2.1092e-04 - loss: 0.0022 - val_bbox_output_loss: 0.0159 - val_bbox_output_mse: 0.0161 - val_class_output_accuracy: 0.9006 - val_class_output_loss: 0.6952 - val_loss: 0.7234
# Epoch 17/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 34s 799ms/step - bbox_output_loss: 0.0015 - bbox_output_mse: 0.0015 - class_output_accuracy: 1.0000 - class_output_loss: 1.7672e-04 - loss: 0.0017 - val_bbox_output_loss: 0.0158 - val_bbox_output_mse: 0.0161 - val_class_output_accuracy: 0.9064 - val_class_output_loss: 0.6834 - val_loss: 0.7118
# Epoch 18/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 820ms/step - bbox_output_loss: 0.0016 - bbox_output_mse: 0.0016 - class_output_accuracy: 1.0000 - class_output_loss: 1.3860e-04 - loss: 0.0018 - val_bbox_output_loss: 0.0163 - val_bbox_output_mse: 0.0165 - val_class_output_accuracy: 0.9006 - val_class_output_loss: 0.6836 - val_loss: 0.7126
# Epoch 19/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 819ms/step - bbox_output_loss: 0.0018 - bbox_output_mse: 0.0018 - class_output_accuracy: 1.0000 - class_output_loss: 1.7604e-04 - loss: 0.0020 - val_bbox_output_loss: 0.0162 - val_bbox_output_mse: 0.0164 - val_class_output_accuracy: 0.9123 - val_class_output_loss: 0.6770 - val_loss: 0.7058
# Epoch 20/20
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 35s 820ms/step - bbox_output_loss: 0.0016 - bbox_output_mse: 0.0016 - class_output_accuracy: 1.0000 - class_output_loss: 1.7710e-04 - loss: 0.0018 - val_bbox_output_loss: 0.0160 - val_bbox_output_mse: 0.0163 - val_class_output_accuracy: 0.9123 - val_class_output_loss: 0.6789 - val_loss: 0.7075

# %%
pred_class_probs, pred_bboxes = model.predict(X_test, verbose=1)
pred_class = np.argmax(pred_class_probs, axis=1)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 290ms/step

# %%
from sklearn.metrics import classification_report

print("Classification Report:")
print(classification_report(cls_test, pred_class, target_names=CLASSES))
# Out:
# Classification Report:
#                        precision    recall  f1-score   support
#
#             with_mask       0.93      0.96      0.95       140
#          without_mask       0.78      0.75      0.77        24
# mask_weared_incorrect       1.00      0.43      0.60         7
#
#              accuracy                           0.91       171
#             macro avg       0.90      0.71      0.77       171
#          weighted avg       0.91      0.91      0.91       171

# %%
def calculate_iou(boxA, boxB):
    # box = [x_min, y_min, x_max, y_max]
    xA = max(boxA[0], boxB[0])
    yA = max(boxA[1], boxB[1])
    xB = min(boxA[2], boxB[2])
    yB = min(boxA[3], boxB[3])

    interArea = max(0, xB - xA) * max(0, yB - yA)
    boxAArea = max(0, boxA[2] - boxA[0]) * max(0, boxA[3] - boxA[1])
    boxBArea = max(0, boxB[2] - boxB[0]) * max(0, boxB[3] - boxB[1])

    unionArea = boxAArea + boxBArea - interArea
    return interArea / unionArea if unionArea != 0 else 0

# %%
ious = []
for true_box, pred_box in zip(bbox_test, pred_bboxes):
    iou = calculate_iou(true_box, pred_box)
    ious.append(iou)

mean_iou = np.mean(ious)
print(f"Mean IoU on Test Set: {mean_iou:.4f}")
# Out:
# Mean IoU on Test Set: 0.2031

# %%
from sklearn.preprocessing import label_binarize

# Make sure cls_test and pred_class_probs are already defined
cls_test_bin = label_binarize(cls_test, classes=[0, 1, 2])

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr = {}
tpr = {}
roc_auc = {}

n_classes = len(CLASSES)

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(cls_test_bin[:, i], pred_class_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# %%
# Plot all ROC curves
plt.figure(figsize=(8, 6))
colors = ['blue', 'green', 'red']

for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2,
             label=f'Class {CLASSES[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves for Multi-Class Classification')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %%
import numpy as np

pred_classes = np.argmax(pred_class_probs, axis=1)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(cls_test, pred_classes)
print(f"Classification Accuracy: {accuracy:.4f}")
# Out:
# Classification Accuracy: 0.9123

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(cls_test, pred_classes)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=CLASSES, yticklabels=CLASSES)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
plt.show()

# %%
import matplotlib.pyplot as plt
import random

# %%
def visualize_predictions(model, X, class_labels, bbox_labels, num_samples=5):
    indices = random.sample(range(len(X)), num_samples)

    for idx in indices:
        image = X[idx]
        true_class = class_labels[idx]
        true_bbox = bbox_labels[idx]

        # Predict
        image_input = np.expand_dims(image, axis=0)
        pred_class_probs, pred_bbox = model.predict(image_input, verbose=0)
        pred_class = np.argmax(pred_class_probs[0])
        pred_bbox = pred_bbox[0]

        # Rescale boxes to image size
        img_disp = (image * 255).astype(np.uint8)
        h, w = img_disp.shape[:2]

        true_box = [int(true_bbox[0]*w), int(true_bbox[1]*h), int(true_bbox[2]*w), int(true_bbox[3]*h)]
        pred_box = [int(pred_bbox[0]*w), int(pred_bbox[1]*h), int(pred_bbox[2]*w), int(pred_bbox[3]*h)]

        # Draw boxes
        img_copy = img_disp.copy()
        cv2.rectangle(img_copy, (pred_box[0], pred_box[1]), (pred_box[2], pred_box[3]), (0,255,0), 2)
        cv2.putText(img_copy, f'Pred: {CLASSES[pred_class]}', (pred_box[0], pred_box[1]-10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,255,0), 2)

        cv2.rectangle(img_copy, (true_box[0], true_box[1]), (true_box[2], true_box[3]), (0,0,255), 2)
        cv2.putText(img_copy, f'True: {CLASSES[true_class]}', (true_box[0], true_box[1]+15), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0,0,255), 2)

        # Show image
        plt.figure(figsize=(6,6))
        plt.imshow(cv2.cvtColor(img_copy, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.title('Green = Prediction | Red = Ground Truth')
        plt.show()

# %%
visualize_predictions(model, X, class_labels, bbox_labels, num_samples=3)

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image, ImageTk
import cv2
import numpy as np

def detect_and_display(image_path):
    # Load and preprocess
    image = cv2.imread(image_path)
    image_resized = cv2.resize(image, (224, 224))
    image_input = image_resized / 255.0
    image_input = np.expand_dims(image_input, axis=0)

    # Predict
    class_probs, bbox_pred = model.predict(image_input, verbose=0)
    class_id = np.argmax(class_probs[0])
    bbox = bbox_pred[0]

    # Denormalize box
    h, w = image.shape[:2]
    x_min = int(bbox[0] * w)
    y_min = int(bbox[1] * h)
    x_max = int(bbox[2] * w)
    y_max = int(bbox[3] * h)

    # Draw prediction
    cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0,255,0), 2)
    cv2.putText(image, CLASSES[class_id], (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0,255,0), 2)

    # Convert to Tkinter-compatible image
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    img_pil = Image.fromarray(image_rgb)
    img_tk = ImageTk.PhotoImage(img_pil)

    # Show in GUI
    label_img.config(image=img_tk)
    label_img.image = img_tk


def browse_image():
    file_path = filedialog.askopenfilename()
    if file_path:
        detect_and_display(file_path)


# GUI setup
root = tk.Tk()
root.title("Face Mask Detection")

btn = tk.Button(root, text="Browse Image", command=browse_image, font=('Arial', 14))
btn.pack(pady=10)

label_img = tk.Label(root)
label_img.pack()

root.mainloop()
